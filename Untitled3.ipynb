# %%
import random
def scramble(s):
    return "".join(random.sample(s, len(s)))

words = [w.strip() for w in open('/usr/share/dict/words') if w == w.lower()]
scrambled = [scramble(w) for w in words]

X = words+scrambled
y = ['word']*len(words) + ['unpronounceable']*len(scrambled)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

text_clf = Pipeline([
    ('vect', CountVectorizer(analyzer='char', ngram_range=(1, 3))),
    ('clf', MultinomialNB())
    ])

text_clf = text_clf.fit(X_train, y_train)
predicted = text_clf.predict(X_test)

from sklearn import metrics
print(metrics.classification_report(y_test, predicted))
# Out:
#                  precision    recall  f1-score   support
#
# unpronounceable       0.93      0.91      0.92     52742
#            word       0.92      0.93      0.92     52602
#
#     avg / total       0.92      0.92      0.92    105344

# %%
import csv
results = []
with open('some_tickers.csv') as csvfile:
    reader = csv.reader(csvfile, quotincsv.QUOTE_NONNUMERIC)
    for row in reader:
        results.append(row)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-bc8313b4fb0c> in <module>()
#       1 import csv
#       2 results = []
# ----> 3 with open('some_tickers.csv') as csvfile:
#       4     reader = csv.reader(csvfile, quotincsv.QUOTE_NONNUMERIC)
#       5     for row in reader:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'some_tickers.csv'

# %%
import pandas
data=pandas.read_csv("/Users/jake/Downloads/All US Equity Tickers.csv")

# %%
data
# Out:
#      Symbol
# 0      AABA
# 1       AAL
# 2      AAME
# 3      AAOI
# 4      AAON
# 5      AAPL
# 6      AAWW
# 7      AAXJ
# 8      AAXN
# 9      ABAC
# 10     ABCB
# 11     ABCD
# 12     ABDC
# 13     ABEO
# 14    ABEOW
# 15     ABIL
# 16     ABIO
# 17     ABMD
# 18     ABTX
# 19     ABUS
# 20     ACAD
# 21     ACBI
# 22     ACER
# 23     ACET
# 24     ACGL
# 25    ACGLO
# 26    ACGLP
# 27     ACHC
# 28     ACHN
# 29     ACHV
# ...     ...
# 8996    XSW
# 8997    XTH
# 8998    XTL
# 8999    XTN
# 9000   XTNT
# 9001   XUSA
# 9002    XVZ
# 9003   XWEB
# 9004   XXII
# 9005   YANG
# 9006    YAO
# 9007    YCL
# 9008    YCS
# 9009   YINN
# 9010    YLD
# 9011   YMLI
# 9012   YMLP
# 9013   YUMA
# 9014    YXI
# 9015    YYY
# 9016   ZCAN
# 9017   ZDEU
# 9018   ZDGE
# 9019   ZGBR
# 9020   ZHOK
# 9021   ZJPN
# 9022   ZMLP
# 9023    ZOM
# 9024   ZROZ
# 9025    ZSL
#
# [9026 rows x 1 columns]

# %%
import pandas as pd
data.head()
a = data['Symbol'].values
a
# Out:
# array(['AABA', 'AAL', 'AAME', ..., 'ZOM', 'ZROZ', 'ZSL'], dtype=object)

# %%
import random
def scramble(s):
    return "".join(random.sample(s, len(s)))

words = [w.strip() for w in open('/usr/share/dict/words') if w == w.lower()]
scrambled = [scramble(w) for w in words]

X = words+scrambled
y = ['word']*len(words) + ['unpronounceable']*len(scrambled)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

text_clf = Pipeline([
    ('vect', CountVectorizer(analyzer='char', ngram_range=(1, 3))),
    ('clf', MultinomialNB())
    ])

text_clf = text_clf.fit(X_train, y_train)
predicted = text_clf.predict(X_test)

from sklearn import metrics
print(metrics.classification_report(y_test, predicted))
# Out:
#                  precision    recall  f1-score   support
#
# unpronounceable       0.93      0.91      0.92     52708
#            word       0.92      0.93      0.93     52636
#
#     avg / total       0.92      0.92      0.92    105344

# %%
import random
def scramble(s):
    return "".join(random.sample(s, len(s)))

words = [w.strip() for w in open('/usr/share/dict/words') if w == w.lower()]
scrambled = [scramble(w) for w in words]

X = words+scrambled
y = ['pronounceable']*len(words) + ['unpronounceable']*len(scrambled)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

text_clf = Pipeline([
    ('vect', CountVectorizer(analyzer='char', ngram_range=(1, 3))),
    ('clf', MultinomialNB())
    ])

text_clf = text_clf.fit(X_train, y_train)
predicted = text_clf.predict(a)

# %%
a
# Out:
# array(['AABA', 'AAL', 'AAME', ..., 'ZOM', 'ZROZ', 'ZSL'], dtype=object)

# %%
predicted
# Out:
# array(['unpronounceable', 'unpronounceable', 'unpronounceable', ...,
#        'word', 'unpronounceable', 'unpronounceable'], dtype='<U15')

# %%
import random
def scramble(s):
    return "".join(random.sample(s, len(s)))

words = [w.strip() for w in open('/usr/share/dict/words') if w == w.lower()]
scrambled = [scramble(w) for w in words]

X = words+scrambled
y = ['pronounceable']*len(words) + ['unpronounceable']*len(scrambled)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

text_clf = Pipeline([
    ('vect', CountVectorizer(analyzer='char', ngram_range=(1, 3))),
    ('clf', MultinomialNB())
    ])

text_clf = text_clf.fit(X_train, y_train)
predicted = text_clf.predict(a)
predicted
# Out:
# array(['unpronounceable', 'unpronounceable', 'unpronounceable', ...,
#        'pronounceable', 'unpronounceable', 'unpronounceable'],
#       dtype='<U15')

# %%
numpy.savetxt("labels.csv", predicted, delimiter=",")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-c7e3b5030cfb> in <module>()
# ----> 1 numpy.savetxt("labels.csv", predicted, delimiter=",")
#
# NameError: name 'numpy' is not defined

# %%
import numpy

# %%
numpy.savetxt("labels.csv", predicted, delimiter=",")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1375                 try:
# -> 1376                     v = format % tuple(row) + newline
#    1377                 except TypeError:
#
# TypeError: must be real number, not numpy.str_
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-c7e3b5030cfb> in <module>()
# ----> 1 numpy.savetxt("labels.csv", predicted, delimiter=",")
#
# /anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1378                     raise TypeError("Mismatch between array dtype ('%s') and "
# ...

# %%
import random
def scramble(s):
    return "".join(random.sample(s, len(s)))

words = [w.strip() for w in open('/usr/share/dict/words') if w == w.lower()]
scrambled = [scramble(w) for w in words]

X = words+scrambled
y = ['pronounceable']*len(words) + ['unpronounceable']*len(scrambled)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

text_clf = Pipeline([
    ('vect', CountVectorizer(analyzer='char', ngram_range=(1, 3))),
    ('clf', MultinomialNB())
    ])

text_clf = text_clf.fit(X_train, y_train)
predicted = text_clf.predict(a)
predicted
# Out:
# array(['unpronounceable', 'unpronounceable', 'unpronounceable', ...,
#        'pronounceable', 'unpronounceable', 'unpronounceable'],
#       dtype='<U15')

# %%
numpy.savetxt("labels.csv", predicted, delimiter=",")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1375                 try:
# -> 1376                     v = format % tuple(row) + newline
#    1377                 except TypeError:
#
# TypeError: must be real number, not numpy.str_
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-c7e3b5030cfb> in <module>()
# ----> 1 numpy.savetxt("labels.csv", predicted, delimiter=",")
#
# /anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1378                     raise TypeError("Mismatch between array dtype ('%s') and "
# ...

# %%
df = pd.DataFrame(predicted)
df.to_csv("labels.csv")

# %%
data=pandas.read_csv("/Users/jake/Downloads/All US Equity Tickers.csv")

# %%
data=pandas.read_csv("/Users/jake/Desktop/All US Mutual Funds.csv")

# %%
data1=pandas.read_csv("/Users/jake/Downloads/All US Equity Tickers.csv")

# %%
import pandas as pd
data.head()
b = data['Symbol'].values
b
# Out:
# array(['AAAAX', 'AAADX', 'AAAGX', ..., 'ZVGNX', 'ZVNBX', 'ZVNIX'],
#       dtype=object)

# %%
import random
def scramble(s):
    return "".join(random.sample(s, len(s)))

words = [w.strip() for w in open('/usr/share/dict/words') if w == w.lower()]
scrambled = [scramble(w) for w in words]

X = words+scrambled
y = ['pronounceable']*len(words) + ['unpronounceable']*len(scrambled)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

text_clf = Pipeline([
    ('vect', CountVectorizer(analyzer='char', ngram_range=(1, 3))),
    ('clf', MultinomialNB())
    ])

text_clf = text_clf.fit(X_train, y_train)
predicted = text_clf.predict(b)
predicted
# Out:
# array(['unpronounceable', 'unpronounceable', 'unpronounceable', ...,
#        'unpronounceable', 'unpronounceable', 'unpronounceable'],
#       dtype='<U15')

# %%
numpy.savetxt("mflabels.csv", predicted, delimiter=",")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1375                 try:
# -> 1376                     v = format % tuple(row) + newline
#    1377                 except TypeError:
#
# TypeError: must be real number, not numpy.str_
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-b56f0a973d53> in <module>()
# ----> 1 numpy.savetxt("mflabels.csv", predicted, delimiter=",")
#
# /anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1378                     raise TypeError("Mismatch between array dtype ('%s') and "
# ...

# %%
import numpy
numpy.savetxt("mflabels.csv", predicted, delimiter=",")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1375                 try:
# -> 1376                     v = format % tuple(row) + newline
#    1377                 except TypeError:
#
# TypeError: must be real number, not numpy.str_
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-dfdd9e5b417b> in <module>()
#       1 import numpy
# ----> 2 numpy.savetxt("mflabels.csv", predicted, delimiter=",")
#
# /anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
# ...

# %%
df = pd.DataFrame(predicted)
df.to_csv("mflabels.csv")

# %%
data=pandas.read_csv("/Users/jake/Downloads/companylist.csv")

# %%
data
# Out:
#      Symbol
# 0        YI
# 1       PIH
# 2     PIHPP
# 3      TURN
# 4      FLWS
# 5      FCCY
# 6      SRCE
# 7      VNET
# 8      TWOU
# 9      TPNL
# 10     JOBS
# 11     EGHT
# 12     AAON
# 13     ABEO
# 14    ABEOW
# 15     ABIL
# 16     ABMD
# 17     AXAS
# 18     ACIU
# 19     ACIA
# 20     ACTG
# 21     ACHC
# 22     ACAD
# 23     ACST
# 24     AXDX
# 25     XLRN
# 26     ANCX
# 27     ARAY
# 28     ACRX
# 29     ACER
# ...     ...
# 6877    WPX
# 6878   WYND
# 6879     WH
# 6880    XYF
# 6881   XFLT
# 6882    XHR
# 6883    XRX
# 6884    XIN
# 6885   XOXO
# 6886    XPO
# 6887    XYL
# 6888    AUY
# 6889   YELP
# 6890   YETI
# 6891   YEXT
# 6892    YRD
# 6893    YPF
# 6894   YUMC
# 6895    YUM
# 6896   ZAYO
# 6897    ZEN
# 6898    ZBH
# 6899   ZB^A
# 6900   ZB^G
# 6901   ZB^H
# 6902    ZBK
# 6903    ZTS
# 6904    ZTO
# 6905    ZUO
# 6906   ZYME
#
# [6907 rows x 1 columns]

# %%
import pandas as pd
data.head()
a = data['Symbol'].values
a
# Out:
# array(['YI', 'PIH', 'PIHPP', ..., 'ZTO', 'ZUO', 'ZYME'], dtype=object)

# %%
import random
def scramble(s):
    return "".join(random.sample(s, len(s)))

words = [w.strip() for w in open('/usr/share/dict/words') if w == w.lower()]
scrambled = [scramble(w) for w in words]

X = words+scrambled
y = ['pronounceable']*len(words) + ['unpronounceable']*len(scrambled)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

text_clf = Pipeline([
    ('vect', CountVectorizer(analyzer='char', ngram_range=(1, 3))),
    ('clf', MultinomialNB())
    ])

text_clf = text_clf.fit(X_train, y_train)
predicted = text_clf.predict(a)
predicted
# Out:
# array(['unpronounceable', 'unpronounceable', 'unpronounceable', ...,
#        'unpronounceable', 'unpronounceable', 'pronounceable'],
#       dtype='<U15')

# %%
df = pd.DataFrame(predicted)
df.to_csv("labels.csv")

# %%
import xlrd 
import pandas
import random
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split

def scramble(s):
    return "".join(random.sample(s, len(s)))

words = [w.strip() for w in open('/usr/share/dict/words') if w == w.lower()]
scrambled = [scramble(w) for w in words]

X = words+scrambled
y = ['pronounceable']*len(words) + ['unpronounceable']*len(scrambled)

X_train, X_test, y_train, y_test = train_test_split(X, y)



text_clf = Pipeline([
    ('vect', CountVectorizer(analyzer='char', ngram_range=(1, 3))),
    ('clf', MultinomialNB())
    ])

text_clf = text_clf.fit(X_train, y_train)

# %%
def frac_pronounc(list):
    count = 0
    for i in list:
        if i == "pronounceable":
            count += 1
    return count/len(list)

# %%
df1=pandas.read_excel("/Users/jake/Desktop/Fine 547 Stata.xlsx")

# %%
funds = list(df1["fund_ticker"])
total = 0
output_file = open("/Users/jake/Desktop/Fine 547 Holdings/result.csv", "w")
matching = []
for fund in funds:
    try:
        fund_df=pandas.read_excel("/Users/jake/Desktop/Fine 547 Holdings/" + fund + ".xlsx")
        total += 1
    except:
        continue
    
    fund_ticks = list(fund_df["Unnamed: 1"][5:])
    est_pronounc = text_clf.predict(fund_ticks)
    
    output = ['NaN', 'NaN', 'NaN', 'Pronouncable', frac_pronounc(est_pronounc)] + [x for x in est_pronounc]
    
    fund_df['prounouncable'] = output
    
    matching.append((fund, frac_pronounc(est_pronounc)))
    
# print(matching)
for (f, v) in matching:
    output_file.write(str(f) + "," + str(v))
    output_file.write("\n")
output_file.close()

# %%
# Out:
# ['PLT',
#  'WSM',
#  'HFC',
#  'CHD',
#  'JWN',
#  'MTN',
#  'MKC',
#  'TRGP',
#  'NJR',
#  'ROL',
#  'DGX',
#  'PII',
#  'JKHY',
#  'MPW',
#  'WPC',
#  'ALE',
#  'NHC',
#  'BR',
#  'GRMN',
#  'R',
#  'XLNX',
#  'HII',
#  'EPR',
#  'RHI',
#  'RS',
#  'OZK',
#  'USPH',
#  'STE',
#  'FUL',
#  'EXR',
#  'RMD',
#  'PHM',
#  'SAFT',
#  'HRC',
#  'EXPD',
#  'ITT',
#  'JBHT',
#  'CBRL',
#  'EV',
#  'RGA',
#  'SON',
#  'MXIM',
#  'AFG',
#  'LDOS',
#  'UMPQ',
#  'SNV',
#  'ZION',
#  'FLIR',
#  'CR',
#  'RJF',
#  'FIGXX',
#  'BMI']

# %%
# Out:
# 57
# 57

# %%
# Out:
#   Portfolio: Aasgard Dividend Growth Sm & Md-Cp N/L Unnamed: 1  \
# 0                        Portfolio Date: 06/30/2018        NaN
# 1                         Date Exported: 11/08/2018        NaN
# 2                                               NaN        NaN
# 3                                              Name     Ticker
# 4                                             Total          –
# 5                                   Plantronics Inc        PLT
# 6                               Williams-Sonoma Inc        WSM
# 7                                HollyFrontier Corp        HFC
# 8                            Church & Dwight Co Inc        CHD
# 9                                     Nordstrom Inc        JWN
#
#            Unnamed: 2 Unnamed: 3                   Unnamed: 4  \
# 0                 NaN        NaN                          NaN
# 1                 NaN        NaN                          NaN
# 2                 NaN        NaN                          NaN
# ...

# %%
import xlrd 
import pandas
import random
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split

def scramble(s):
    return "".join(random.sample(s, len(s)))

words = [w.strip() for w in open('/usr/share/dict/words') if w == w.lower()]
scrambled = [scramble(w) for w in words]

X = words+scrambled
y = ['pronounceable']*len(words) + ['unpronounceable']*len(scrambled)

X_train, X_test, y_train, y_test = train_test_split(X, y)



text_clf = Pipeline([
    ('vect', CountVectorizer(analyzer='char', ngram_range=(1, 3))),
    ('clf', MultinomialNB())
    ])

text_clf = text_clf.fit(X_train, y_train)
data5=pandas.read_csv("/Users/jake/Downloads/T. Rowe Price Established Growth A ML File.csv")
import pandas as pd
data.head()
a = data['Symbol'].values
a
predicted = text_clf.predict(a)
predicted
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd0 in position 0: unexpected end of data
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-106-12fbadd4d5ee> in <module>()
#      26
#      27 text_clf = text_clf.fit(X_train, y_train)
# ---> 28 data5=pandas.read_csv("/Users/jake/Downloads/T. Rowe Price Established Growth A ML File.csv")
#      29 import pandas as pd
#      30 data.head()
#
# ...
